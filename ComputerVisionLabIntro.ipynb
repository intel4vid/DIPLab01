# %% [markdown]
# # Computer Vision Lab - Working with visual datasets
#
# The goal of this lab is to introduce you to visual datasets collection and preprocessing before you start building and deploying your computer vision model.
#
# <br><br>

# %% [markdown]
# <img src="./images/VisualDataML.png">

# %% [markdown]
# <br><br><br><br><br>

# %% [markdown]
# <img src="./images/ImportanceBigData.png">

# %% [markdown]
# <br><br><br><br><br>

# %% [markdown]
# <img src="./images/ModelML.png">

# %% [markdown]
# <br><br><br><br><br>

# %% [markdown]
# <img src="./images/DeepLearning.png">

# %% [markdown]
# <br><br><br><br><br>

# %% [markdown]
# <img src="./images/MLCategories.png">

# %% [markdown]
# <br><br><br><br><br>

# %% [markdown]
# # Keras
#
# Keras is a model-level library, providing high-level building blocks for developing deep learning models. It does not handle low-level operations such as tensor products, convolutions and so on itself.
# <img src="https://keras.io/img/keras-logo-small.jpg" width="140">
#
# Keras development is backed primarily by Google, and the Keras API comes packaged in TensorFlow as tf.keras. Additionally, Microsoft maintains the CNTK Keras backend. Amazon AWS is maintaining the Keras fork with MXNet support. Other contributing companies include NVIDIA, Uber, and Apple (with CoreML).
#
# <img src="./images/KerasStack.png">
#
#
# ## Keras backend
# Keras relies on a specialized, well optimized tensor manipulation library to do so, serving as the "backend engine" of Keras. Rather than picking one single tensor library and making the implementation of Keras tied to that library, Keras handles the problem in a modular way, and several different backend engines can be plugged seamlessly into Keras.
#
# At this time, Keras has three backend implementations available: the TensorFlow backend, the Theano backend, and the CNTK backend.
#
# * [TensorFlow](https://www.tensorflow.org/lite) is an open-source symbolic tensor manipulation framework developed by Google.
# * [Theano](http://deeplearning.net/software/theano/) is an open-source symbolic tensor manipulation framework developed by LISA Lab at Université de Montréal.Theano is a Python library that allows you to define, optimize, and evaluate mathematical expressions involving multi-dimensional arrays efficiently. The latest release of Theano was on 2017/11/15.
# * [CNTK](https://docs.microsoft.com/en-us/cognitive-toolkit/) is an open-source toolkit for deep learning developed by Microsoft. It describes neural networks as a series of computational steps via a directed graph. CNTK allows the user to easily realize and combine popular model types such as feed-forward DNNs, convolutional neural networks (CNNs) and recurrent neural networks (RNNs/LSTMs). CNTK implements stochastic gradient descent (SGD, error backpropagation) learning with automatic differentiation and parallelization across multiple GPUs and servers.<br><br><br><br>
#
#
# ## Keras popularity
#
# <img src="./images/KerasPop01.png" width="600">
# <br><br>
# <img src="./images/KerasPop02.png" width="600">
# <br><br><br><br><br>

# %% [markdown]
# # The Keras Ecosystem
#
# * ### [Keras Tuner](https://keras-team.github.io/keras-tuner/)
# scalable hyperparameter search framework
# * ### [AutoKeras](https://autokeras.com/)
# widely accessible and easy to learn and use machine learning AutoML system based on Keras
# * ### [TensorFlow Cloud](https://github.com/tensorflow/cloud)
# set of utilities for running large-scale Keras training jobs on Google Cloud Platform
# * ### [TensorFlow.js](https://www.tensorflow.org/js)
# used for running TF models in the browser or on a Node.js server
# * ### [TensorFlow Lite](https://www.tensorflow.org/lite)
# open source deep learning framework for deploying ML models on mobile and IoT devices
# * ### [Model optimization toolkit](https://www.tensorflow.org/model_optimization)
# toolkit is used to make ML models faster and more memory and power efficient
# * ### [TFX integration](https://www.tensorflow.org/tfx)
# ML platform for deploying and maintaining production machine learning pipelines
#
# <br><br><br><br><br>

# %% [markdown]
# # Interoperability and Compatibility
# Keras also supports the [ONNX](https://onnx.ai/) format.
#
# <img src="https://onnx.ai/assets/mlogo.png" width="140">
#
# ONNX is a open format to represent deep learning models. With ONNX, AI developers can more easily move models between state-of-the-art tools and choose the combination that is best for them. ONNX is developed and supported by a community of partners.
#
# <img src="./images/ONNXCommunity.png">
#
# The keras2onnx model converter enables users to convert Keras models into the ONNX model format. Initially, the Keras converter was developed in the project onnxmltools. To support more kinds of Keras models and reduce the complexity of mixing multiple converters, keras2onnx was created to convert the Keras model only.
# <br><br><br><br><br>

# %% [markdown]
# # End to end ML model requirements
#
# #### 1. Acquiring/Creating a dataset
# #### 2. Preparing a dataset
# #### 3. Dataset split to train and test data
# #### 4. Training the ML model
# #### 5. The ML model validation
# #### 6. ML deployment
#
# <br><br>

# %% [markdown]
# # Datasets

# %% [markdown]
# ### 1. [CIFAR-10/100](https://www.cs.toronto.edu/~kriz/cifar.html) dataset
# Dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
# <img src="./images/CIFAR.png" width="500">
#
# ### 2. [MNIST](http://yann.lecun.com/exdb/mnist/) Dataset
# The MNIST database has a training set of 60,000 examples, and a test set of 10,000 examples.
# <img src="./images/MNIST.png" width="500">
#
# ### 3. IMDB-Wiki Dataset
# Dataset has 520k images - gender and age prediction.
# <img src="./images/IMDB.png" width="500">
#
# ### 4. [ImageNet](http://www.image-net.org/challenges/LSVRC/) dataset
# Evaluation of object detection and image classification algorithms.
# <img src="./images/imagenet.jpeg" width="500">
#
# ### 5. Places2 Database dataset
# Dateaset has more than 10 million images and over 400 scenes. It is used for scene classification and scene parsing.
# <img src="./images/Places.png" width="500">
#
# ### 6. [COCO](http://cocodataset.org/#external) dataset
# A large-scale object detection, segmentation, and captioning dataset with several features including Object segmentation, Recognition in context, Superpixel stuff segmentation, 330K images (>200K labeled), 1.5 million object instances, 80 object categories, 91 stuff categories, 5 captions per image, 250,000 people with keypoints.
# <img src="./images/COCO.png" width="500">
#
# ### 7. [Kaggle Datasets Collection](https://www.kaggle.com/datasets)
# Kaggle enables you to search among 36924 datasets.
# <img src="./images/KaggleData.png" width="500">

# %% [markdown]
# <br><br><br>

# %% [markdown]
# # 1. Collecting remote dataset

# %% [markdown]
# #### Data collecting
# Neural networks process vectorized & standardized representations (e.g. images are read and decoded into integer tensors, converted to floating point dtypes and normalized to range between 0 and 1. In case of Keras the images can be manipulated as numpy arrays (e.g. skimage), as TensorFlow dataset objects or batches of data yielded by Python generators (e.g. keras.utils.Sequence class)
#
# The following Keras commands turn raw data on disk into a Dataset:
#
# * tf.keras.preprocessing.image_dataset_from_directory turns image files sorted into class-specific folders into a labeled dataset of image tensors.
# * tf.keras.preprocessing.text_dataset_from_directory does the same for text files.

# %%
# installing tensorflow in virt env requires the following inst command 
import os
import time
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#!curl -O https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip

# %%
#!unzip -q kagglecatsanddogs_3367a.zip
import shutil
#shutil.unpack_archive('kagglecatsanddogs_3367a.zip')

# %% [markdown]
# Now we have a PetImages folder which contain two subfolders, Cat and Dog. Each subfolder contains image files for each category.

# %%
os.listdir('PetImages')
# Out:
# ['Cat', 'Dog']

# %% [markdown]
# ## Find and remove corrupted images

# %% [markdown]
# Let's check if the downloaded dog/cat dataset contains corrupted images and remove them if that is the case. Filtering and removal process is based on missing "JFIF" string that can be found in image header.
# *The JPEG File Interchange Format (JFIF) is an image file format standard. It defines supplementary specifications for the container format that contains the image data encoded with the JPEG algorithm. The base specifications for a JPEG container format are defined in Annex B of the JPEG standard, known as JPEG Interchange Format (JIF). JFIF builds over JIF to solve some of JIF's limitations, including unnecessary complexity, component sample registration, resolution, aspect ratio, and color space.*

# %%
num_skipped = 0
for folder_name in ("Cat", "Dog"):
    folder_path = os.path.join("PetImages", folder_name)
    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        try:
            fobj = open(fpath, "rb")
            is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
        finally:
            fobj.close()

        if not is_jfif:
            num_skipped += 1
            # Delete corrupted image
            os.remove(fpath)

print("Deleted %d images" % num_skipped)
# Out:
# Deleted 0 images

# %% [markdown]
# ### Create Dataset

# %%
# declare image size
image_size = (180, 180)
# declare batch size
batch_size = 32

# create training data set using image_dataset_from_directory function 
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "PetImages",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)

# create validation data set
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "PetImages",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 23422 files belonging to 2 classes.
# Using 18738 files for training.
# Found 23422 files belonging to 2 classes.
# Using 4684 files for validation.

# %% [markdown]
# ### Visualize image data
# Visualise 25 images from a training set with labels as titles (1 is dog 0 is cat).

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 15))
for images, labels in train_ds.take(1):
    for i in range(25):
        ax = plt.subplot(5, 5, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %% [markdown]
# ### Add additional images by using image augmentation
# Sometimes original image datasets can be expanded and filled with artifically generated images. These artificially generated images are result of image transformations performed on images taken from the original dataset. This process is called image augmentation and it is performed in order to make the dataset more complex (e.g. prevent overfitting).

# %%
data_augmentation = keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("vertical"),
    layers.experimental.preprocessing.RandomRotation(0.5),
])

# %% [markdown]
# #### Visualize the transformed images

# %%
plt.figure(figsize=(15, 15))
for images, _ in train_ds.take(1):
    for i in range(25):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(5, 5, i + 1)
        plt.imshow(augmented_images[5].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ## Options for image augmentation

# %% [markdown]
# #### 1. RandomContrast
# class RandomContrast: Adjust the contrast of an image or images by a random factor. Computes the global mean for each input channel/image and then computes the x of each pixel in the output image accordig to *(x - mean) * contrast_factor + mean*.

# %% [markdown]
# ```layers.experimental.preprocessing.RandomContrast(factor)```

# %% [markdown]
# ```Example:
# layers.experimental.preprocessing.RandomContrast(0.7)```

# %% [markdown]
# #### 2. RandomCrop
# class RandomCrop: Randomly crop the images to target height and width.

# %% [markdown]
# ```layers.experimental.preprocessing.RandomCrop(height, width)```

# %% [markdown]
# ```Example:
# layers.experimental.preprocessing.RandomCrop(250, 250)```

# %% [markdown]
# #### 3. RandomFlip
# class RandomFlip: Randomly flip each image horizontally and vertically. Values can be "horizontal", "vertical", or "horizontal_and_vertical".

# %% [markdown]
# ```layers.experimental.preprocessing.RandomFlip( mode=HORIZONTAL_AND_VERTICAL, seed=None, name=None, **kwargs)```

# %% [markdown]
# ```Example:
# layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(img_height, img_width, number_of_channels))
# layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(100, 100, 3))```

# %% [markdown]
# #### 4. RandomHeight
# class RandomHeight: Randomly vary the height of a batch of images during training.

# %% [markdown]
# ```layers.experimental.preprocessing.RandomHeight(factor, interpolation='bilinear', seed=None, name=None, **kwargs)```

# %% [markdown]
# #### 5. RandomRotation
# class RandomRotation: Randomly rotate each image. Values: height_factor=(0.2, 0.3) result in an output zoomed out by a random amount in the range [+20%, +30%]. height_factor=(-0.3, -0.2) result in an output zoomed in by a random amount in the range [+20%, +30%]. Values for fill_mode:'constant', 'reflect', 'wrap', 'nearest'.

# %% [markdown]
# ```Example:
# layers.experimental.preprocessing.RandomZoom(height_factor, width_factor=None,fill_mode='reflect',interpolation='bilinear', seed=None, name=None, fill_value=0.0,**kwargs)```

# %%
input_img = np.random.random((32, 224, 224, 3))
layer = tf.keras.layers.experimental.preprocessing.RandomZoom(.5, .2)
out_img = layer(input_img)
out_img.shape
plt.imshow(out_img[0])

# %% [markdown]
# #### 6. RandomZoom
# class RandomZoom: Randomly zoom each image during training.Values: height_factor=(0.2, 0.3) result in an output zoomed out by a random amount in the range [+20%, +30%]. height_factor=(-0.3, -0.2) result in an output zoomed in by a random amount in the range [+20%, +30%]. Values for fill_mode:'constant', 'reflect', 'wrap', 'nearest'.

# %% [markdown]
# ```layers.experimental.preprocessing.RandomZoom(height_factor, width_factor=None, fill_mode='reflect', interpolation='bilinear', seed=None, name=None, fill_value=0.0,**kwargs)```

# %% [markdown]
# ```Example:
# layers.experimental.preprocessing.RandomZoom(0.1)```

# %% [markdown]
# #### 7. Rescaling
# class Rescaling: Multiply inputs by scale and adds offset. To rescale an input in the [0, 255] range to be in the [0, 1] range, you would pass scale=1./255.
#
# To rescale an input in the [0, 255] range to be in the [-1, 1] range, you would pass scale=1./127.5, offset=-1.

# %% [markdown]
# ```layers.experimental.preprocessing.Rescaling(scale, offset=0.0, name=None, **kwargs)```

# %% [markdown]
# ```Example:
# layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3))```

# %% [markdown]
# #### 8. Resizing
# class Resizing: Image resizing layer. Interpolation values: bilinear, nearest, bicubic, area, lanczos3, lanczos5, gaussian, mitchellcubic.

# %% [markdown]
# ```layers.experimental.preprocessing.Resizing(height, width, interpolation='bilinear')```

# %% [markdown]
# # Exercise - DIP: Augmentation
#
# The goal of this exercise is to get familiar with image dataset preparations. This includes loading, visualizing and transforming of images.
#
# 1. Read the image from the Cat/Dog image dataset and perform a horizontal RandomFlip transformation
# 1. Visualize the result of performed horizontal RandomFlip transformation
# 1. Read a group of images from the Cat/Dog image dataset and perform a RandomZoom transformation
# 1. Visualize the result of performed horizontal RandomFlip transformation
# 1. Print out the type, number of dimensions, size, shape of the image.

# %% [markdown]
# # 2. Acquiring Visual Datasets via API
# The image datasets can be downloaded using cloud cognitive services such as MS Azure Bing Search API, or Google API or Amazon API for image searching. The [BING image search API](https://www.microsoft.com/en-us/bing/apis/bing-image-search-api) enables you to check out how image search works in your browser.

# %% [markdown]
# ### Install using pip install azure-cognitiveservices-search-imagesearch

# %%
# !pip install azure-cognitiveservices-search-imagesearch
# Out:
# Requirement already satisfied: azure-cognitiveservices-search-imagesearch in c:\labanalytics\lab01\lib\site-packages (2.0.0)
# Requirement already satisfied: msrestazure<2.0.0,>=0.4.32 in c:\labanalytics\lab01\lib\site-packages (from azure-cognitiveservices-search-imagesearch) (0.6.4)
# Requirement already satisfied: msrest>=0.5.0 in c:\labanalytics\lab01\lib\site-packages (from azure-cognitiveservices-search-imagesearch) (0.6.21)
# Requirement already satisfied: azure-common~=1.1 in c:\labanalytics\lab01\lib\site-packages (from azure-cognitiveservices-search-imagesearch) (1.1.26)
# Requirement already satisfied: isodate>=0.6.0 in c:\labanalytics\lab01\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-search-imagesearch) (0.6.0)
# Requirement already satisfied: requests~=2.16 in c:\labanalytics\lab01\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-search-imagesearch) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\labanalytics\lab01\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-search-imagesearch) (2020.12.5)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\labanalytics\lab01\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-search-imagesearch) (1.3.0)
# Requirement already satisfied: six in c:\labanalytics\lab01\lib\site-packages (from isodate>=0.6.0->msrest>=0.5.0->azure-cognitiveservices-search-imagesearch) (1.15.0)
# Requirement already satisfied: adal<2.0.0,>=0.6.0 in c:\labanalytics\lab01\lib\site-packages (from msrestazure<2.0.0,>=0.4.32->azure-cognitiveservices-search-imagesearch) (1.2.6)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\labanalytics\lab01\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-cognitiveservices-search-imagesearch) (2.0.1)
# Requirement already satisfied: cryptography>=1.1.0 in c:\labanalytics\lab01\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-cognitiveservices-search-imagesearch) (3.4.6)
# Requirement already satisfied: python-dateutil<3,>=2.1.0 in c:\labanalytics\lab01\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-cognitiveservices-search-imagesearch) (2.8.1)
# Requirement already satisfied: cffi>=1.12 in c:\labanalytics\lab01\lib\site-packages (from cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-cognitiveservices-search-imagesearch) (1.14.5)
# Requirement already satisfied: pycparser in c:\labanalytics\lab01\lib\site-packages (from cffi>=1.12->cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-cognitiveservices-search-imagesearch) (2.20)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\labanalytics\lab01\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-search-imagesearch) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\labanalytics\lab01\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-search-imagesearch) (1.26.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\labanalytics\lab01\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-search-imagesearch) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\labanalytics\lab01\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-cognitiveservices-search-imagesearch) (3.1.0)

# %%
# !pip install azure-cognitiveservices-search-visualsearch
# Out:
# Requirement already satisfied: azure-cognitiveservices-search-visualsearch in c:\labanalytics\lab01\lib\site-packages (0.2.0)
# Requirement already satisfied: msrest>=0.5.0 in c:\labanalytics\lab01\lib\site-packages (from azure-cognitiveservices-search-visualsearch) (0.6.21)
# Requirement already satisfied: azure-common~=1.1 in c:\labanalytics\lab01\lib\site-packages (from azure-cognitiveservices-search-visualsearch) (1.1.26)
# Requirement already satisfied: requests~=2.16 in c:\labanalytics\lab01\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-search-visualsearch) (2.25.1)
# Requirement already satisfied: isodate>=0.6.0 in c:\labanalytics\lab01\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-search-visualsearch) (0.6.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\labanalytics\lab01\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-search-visualsearch) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\labanalytics\lab01\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-search-visualsearch) (2020.12.5)
# Requirement already satisfied: six in c:\labanalytics\lab01\lib\site-packages (from isodate>=0.6.0->msrest>=0.5.0->azure-cognitiveservices-search-visualsearch) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\labanalytics\lab01\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-search-visualsearch) (1.26.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\labanalytics\lab01\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-search-visualsearch) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\labanalytics\lab01\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-search-visualsearch) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\labanalytics\lab01\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-cognitiveservices-search-visualsearch) (3.1.0)

# %% [markdown]
# ### Import necessary packages

# %%
from azure.cognitiveservices.search.imagesearch import ImageSearchClient
from msrest.authentication import CognitiveServicesCredentials
import requests
from requests import exceptions
import cv2
import os
import matplotlib.pyplot as plt
from PIL import Image
from io import BytesIO

# %% [markdown]
# ### Prerequisites

# %% [markdown]
# Below are the steps to create a Bing Search Service resource through Azure Marketplace and get your key.
#
# 1. Go to [Azure Portal](https://portal.azure.com/#home) and sign in with your Microsoft account. If you don't have a Microsoft account, click Create one.
# 2. From the portal, type Bing in the search box.
# <br>
# <img src="./images/BingResource.png">
# <br>
#
# 3. Under Marketplace in the search results, select the Bing service you're interested in (for example, Bing Search or Bing Custom Search).
# <br>
# <img src="./images/BingSearch.png">
# <br>
# 4. If you have a free trial or pay account, skip to Create your Bing resource.
#
# <br>
# <img src="./images/BingCreate.png">
# <br>
#
# 5. On the Create a free account splash screen, click Start free.
#
# 6. Next, you have the option of continuing with the free trial (click Start free again) or paying for an Azure subscription (click Or buy now). You can always start with the free trial and pay for a subscription later.
#
# 7. Enter a resource name. Names may contain alphanumeric characters and dashes (-) only.
#
# 8. The Subscription field could be set to Free Trial or select your appropriate subscription.
#
# 9. In the Pricing tier dropdown, select Free F1 package. The other packages are for the pay model. To view package options and pricing for the pay model, click View full pricing details.
#
# 10. If you have an existing resource group that you want to add this resource to, select it from the Resource group dropdown list. Otherwise, click Create new to create a resource group.
#
# 11. Select a location from the Resource group location dropdown. The location is where the metadata associated with your account resides and has no impact on runtime availability.
#
# 12. Click the check the box to indicate that you have read and understood the notice.
#
# The following image shows filled Create form.
# <br>
# <img src="./images/BingContainer.png">
# <br>
#
# 13. Click Create. This starts the deployment process, which can take several minutes.
#
# 14. When the deployment process completes, click Go to resource.
#
# <br>
# <img src="./images/BingGoTo.png">
# <br>
#
# 15. To get your subscription key to use in API calls, click Keys and Endpoint in the left pane.
#
# <br>
# <img src="./images/BingKey.png">
# <br>
#
#
# The keys are used to access your Bing resource. Do not share your keys. Only one key is necessary to make an API call. When regenerating the first key, you can use the second key for continued access to the service.

# %% [markdown]
# ### Create variables for your subscription key and search term

# %%
subscription_key = 'acd3c4908e9a455a90e65ad33a0a7f9a'
#subscription_endpoint = 'https://api.cognitive.microsoft.com/bing/v7.0/images/search'
subscription_endpoint = 'https://api.bing.microsoft.com/v7.0/images/search'

max_images=20
group_size=5
search_term = "car"

# %%
# when attempting to download images from the web both the Python programming language and the requests library have a number of
# exceptions that can be thrown so let's build a list of them now so we can filter on them
EXCEPTIONS = set([IOError, FileNotFoundError,exceptions.RequestException, exceptions.HTTPError, exceptions.ConnectionError, exceptions.Timeout])

# %%
# store the search term in a variable then set the headers and search parameters
term = search_term
headers = {"Ocp-Apim-Subscription-Key" : subscription_key}
params = {"q": term, "offset": 0, "count": group_size} #, 'maxHeight':200 , 'maxWidth':200

# %%
# make the search
print("Searching Bing API for '{}'".format(term))
search = requests.get(subscription_endpoint, headers=headers, params=params)
search.raise_for_status()
# Out:
# Searching Bing API for 'car'

# %%
# grab the results from the search, including the total number of estimated results returned by the Bing API
# totalEstimatedMatches	The estimated number of images that are relevant to the query. 
# Use this number along with the count and offset query parameters to page the results.

results = search.json()
estNumResults = min(results["totalEstimatedMatches"], max_images)
print("There are {} search results for '{}'".format(estNumResults,term))

# initialize the total number of images downloaded thus far
total = 0
# Out:
# There are 20 search results for 'car'

# %%
# loop over the estimated number of results in `group_size` groups
for offset in range(0, estNumResults, group_size):

    # update the search parameters using the current offset, then make the request to fetch the results
    print("Making request for group {}-{} of {}...".format(offset, offset + group_size, estNumResults))
    params["offset"] = offset
    time.sleep(2)
    search = requests.get(subscription_endpoint, headers=headers, params=params)
    search.raise_for_status()
    results = search.json()
    #print(results)
    #print("Saving images for group {}-{} of {}...".format(offset, offset + group_size, estNumResults))
# Out:
# Making request for group 0-5 of 20...
# Making request for group 5-10 of 20...
# Making request for group 10-15 of 20...
# Making request for group 15-20 of 20...

# %%
ROOT_DIR=os.getcwd()
output_dir=os.path.join(ROOT_DIR,search_term)
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
print('Folder exist')
# Out:
# Folder exist

# %%
results
# Out:
# {'_type': 'Images',
#  'instrumentation': {'_type': 'ResponseInstrumentation'},
#  'readLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=car',
#  'webSearchUrl': 'https://www.bing.com/images/search?q=car&FORM=OIIARP',
#  'queryContext': {'originalQuery': 'car',
#   'alterationDisplayQuery': 'car',
#   'alterationOverrideQuery': '+car',
#   'alterationMethod': 'AM_JustChangeIt',
#   'alterationType': 'CombinedAlterationsChained'},
#  'totalEstimatedMatches': 183,
#  'nextOffset': 20,
#  'currentOffset': 15,
#  'value': [{'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&q=car&id=17AA5D8D70A638716D1D8170062E8C051DAC4135&simid=608008128973051763',
#    'name': "Sony has its own electric car? Yes, and it's called the ...",
#    'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.nnFLmgjlDJvicpMsFol8wgHaEz&pid=Api',
#    'datePublished': '2020-01-07T08:51:00.0000000Z',
#    'isFamilyFriendly': True,
#    'contentUrl': 'https://images.tweaktown.com/news/6/9/69796_03_sony-electric-car-yes-called-vision_full.png',
#    'hostPageUrl': 'https://www.tweaktown.com/news/69796/sony-electric-car-yes-called-vision/index.html',
#    'contentSize': '859876 B',
#    'encodingFormat': 'png',
#    'hostPageDisplayUrl': 'https://www.tweaktown.com/news/69796/sony-electric-car-yes-called-vision/index.html',
#    'width': 1300,
#    'height': 843,
#    'hostPageFavIconUrl': 'https://www.bing.com/th?id=ODF.8TzUfKnXPVlDldJZOhnnrw&pid=Api',
#    'hostPageDomainFriendlyName': 'TweakTown',
#    'hostPageDiscoveredDate': '2020-01-07T00:00:00.0000000Z',
#    'thumbnail': {'width': 474, 'height': 307},
#    'imageInsightsToken': 'ccid_nnFLmgjl*cp_C842556E255FA9A60B3957D407E355E4*mid_17AA5D8D70A638716D1D8170062E8C051DAC4135*simid_608008128973051763*thid_OIP.nnFLmgjlDJvicpMsFol8wgHaEz',
#    'insightsMetadata': {'pagesIncludingCount': 5, 'availableSizesCount': 3},
#    'imageId': '17AA5D8D70A638716D1D8170062E8C051DAC4135',
#    'accentColor': '946237'},
#   {'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&q=car&id=88471B91D9FB937CD34B755BFA913102A041031E&simid=608048196725507303',
#    'name': 'Car News: Sports cars',
#    'thumbnailUrl': 'https://tse4.mm.bing.net/th?id=OIP.0Llaj0NHfvq5bz7pvONz6QHaFj&pid=Api',
#    'datePublished': '2020-05-15T13:09:00.0000000Z',
#    'isFamilyFriendly': True,
#    'contentUrl': 'http://4.bp.blogspot.com/-6qW6H-KSJtM/TpA_xtD7NvI/AAAAAAAADXA/WMwNngDkPoE/s1600/sports-cars-pictures-car.jpg',
#    'hostPageUrl': 'http://rubenblack.blogspot.com/2011/10/sports-cars.html',
#    'contentSize': '133658 B',
#    'encodingFormat': 'jpeg',
#    'hostPageDisplayUrl': 'rubenblack.blogspot.com/2011/10/sports-cars.html',
#    'width': 1600,
#    'height': 1200,
#    'hostPageFavIconUrl': 'https://www.bing.com/th?id=ODF.kCKFU1-d0l3Elu2Vvbpmew&pid=Api',
#    'hostPageDomainFriendlyName': 'blogspot.com',
#    'hostPageDiscoveredDate': '2013-07-06T00:00:00.0000000Z',
#    'thumbnail': {'width': 474, 'height': 355},
#    'imageInsightsToken': 'ccid_0Llaj0NH*cp_D58923BCE948C25A72D596C0B51C1030*mid_88471B91D9FB937CD34B755BFA913102A041031E*simid_608048196725507303*thid_OIP.0Llaj0NHfvq5bz7pvONz6QHaFj',
#    'insightsMetadata': {'recipeSourcesCount': 0,
#     'pagesIncludingCount': 345,
#     'availableSizesCount': 86},
#    'imageId': '88471B91D9FB937CD34B755BFA913102A041031E',
#    'accentColor': 'C68C05'},
#   {'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&q=car&id=9E8B1315BF9A4B7A9B1BEC95541651451291EF13&simid=608022912255359893',
#    'name': 'KIA Convertibles & Sportscars coming? - Photos',
#    'thumbnailUrl': 'https://tse1.mm.bing.net/th?id=OIP.-dslUuRSTdoMhurF7DsTKAHaEz&pid=Api',
#    'datePublished': '2018-04-26T05:39:00.0000000Z',
#    'isFamilyFriendly': True,
#    'contentUrl': 'https://s3.caradvice.com.au/wp-content/uploads/2010/11/215_Kia_Kee_01-e1288670518879.jpg',
#    'hostPageUrl': 'https://www.caradvice.com.au/89978/kia-convertibles-sportscars-coming/photos/',
#    'contentSize': '83967 B',
#    'encodingFormat': 'jpeg',
#    'hostPageDisplayUrl': 'https://www.caradvice.com.au/89978/kia-convertibles-sportscars-coming/photos',
#    'width': 1069,
#    'height': 694,
#    'hostPageFavIconUrl': 'https://www.bing.com/th?id=ODF.9Uh4Rq2PSsjBgET_pM1F_w&pid=Api',
#    'hostPageDomainFriendlyName': 'CarAdvice',
#    'hostPageDiscoveredDate': '2018-03-24T00:00:00.0000000Z',
#    'thumbnail': {'width': 474, 'height': 307},
#    'imageInsightsToken': 'ccid_+dslUuRS*cp_EE19165D352EF351EA98BF8BB3E9FE48*mid_9E8B1315BF9A4B7A9B1BEC95541651451291EF13*simid_608022912255359893*thid_OIP.-dslUuRSTdoMhurF7DsTKAHaEz',
#    'insightsMetadata': {'pagesIncludingCount': 9, 'availableSizesCount': 5},
#    'imageId': '9E8B1315BF9A4B7A9B1BEC95541651451291EF13',
#    'accentColor': '7C903B'},
#   {'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&q=car&id=6321B0D1526910D6E294561166DD33FEA96ECBBA&simid=608005994375755584',
#    'name': 'wallpapers: Bugatti Veyron',
#    'thumbnailUrl': 'https://tse1.mm.bing.net/th?id=OIP.SwiwL2sjsDZ-jPp-Nh3pWAHaFj&pid=Api',
#    'datePublished': '2019-04-14T10:29:00.0000000Z',
#    'isFamilyFriendly': True,
#    'contentUrl': 'http://2.bp.blogspot.com/-xOYTiTbto1g/UEWQEHfBcYI/AAAAAAAAJFo/IrHrNVrsGoY/s1600/Bugatti+Veyron+Car+Wallpapers+3.jpg',
#    'hostPageUrl': 'http://wallpapers-xs.blogspot.com/2012/09/bugatti-veyron.html',
#    'contentSize': '83426 B',
#    'encodingFormat': 'jpeg',
#    'hostPageDisplayUrl': 'wallpapers-xs.blogspot.com/2012/09/bugatti-veyron.html',
#    'width': 1600,
#    'height': 1200,
#    'hostPageFavIconUrl': 'https://www.bing.com/th?id=ODF.kCKFU1-d0l3Elu2Vvbpmew&pid=Api',
#    'hostPageDomainFriendlyName': 'blogspot.com',
#    'hostPageDiscoveredDate': '2013-07-06T00:00:00.0000000Z',
#    'thumbnail': {'width': 474, 'height': 355},
#    'imageInsightsToken': 'ccid_SwiwL2sj*cp_B123753FDD45A955E614F415274EB2CE*mid_6321B0D1526910D6E294561166DD33FEA96ECBBA*simid_608005994375755584*thid_OIP.SwiwL2sjsDZ-jPp-Nh3pWAHaFj',
#    'insightsMetadata': {'recipeSourcesCount': 0,
#     'pagesIncludingCount': 190,
#     'availableSizesCount': 79},
#    'imageId': '6321B0D1526910D6E294561166DD33FEA96ECBBA',
#    'accentColor': '6A3F36'},
#   {'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&q=car&id=E854475D28FEB7925D51D47F6F4B9688D21D1FCC&simid=608047226062517058',
#    'name': 'Sports cars Wallpaper - We Need Fun',
#    'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.ziQq3wrdIhUvHqgAIckw3gHaEo&pid=Api',
#    'datePublished': '2020-06-24T13:11:00.0000000Z',
#    'isFamilyFriendly': True,
#    'contentUrl': 'https://weneedfun.com/wp-content/uploads/2015/10/Sports-car-16.jpg',
#    'hostPageUrl': 'https://weneedfun.com/sports-cars-wallpaper/',
#    'contentSize': '793171 B',
#    'encodingFormat': 'jpeg',
#    'hostPageDisplayUrl': 'https://weneedfun.com/sports-cars-wallpaper',
#    'width': 1920,
#    'height': 1200,
#    'hostPageDiscoveredDate': '2017-05-04T00:00:00.0000000Z',
#    'thumbnail': {'width': 474, 'height': 296},
#    'imageInsightsToken': 'ccid_ziQq3wrd*cp_B27B732FCCDBD7BB60B715977DD9669A*mid_E854475D28FEB7925D51D47F6F4B9688D21D1FCC*simid_608047226062517058*thid_OIP.ziQq3wrdIhUvHqgAIckw3gHaEo',
#    'insightsMetadata': {'recipeSourcesCount': 0,
#     'pagesIncludingCount': 19,
#     'availableSizesCount': 6},
#    'imageId': 'E854475D28FEB7925D51D47F6F4B9688D21D1FCC',
#    'accentColor': '0285C9'}],
#  'queryExpansions': [{'text': 'Modern Cars',
#    'displayText': 'Modern',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Modern+Cars&tq=%7b%22pq%22%3a%22car%22%2c%22qs%22%3a%5b%7b%22cv%22%3a%22car%22%2c%22pv%22%3a%22car%22%2c%22hps%22%3atrue%2c%22iqp%22%3afalse%7d%2c%7b%22cv%22%3a%22Modern%22%2c%22pv%22%3a%22%22%2c%22hps%22%3afalse%2c%22iqp%22%3atrue%7d%5d%7d&FORM=IRPATC',
#      'thumbnail': {'thumbnailUrl': 'https://tse3.mm.bing.net/th?q=Ratatouille+Movie&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#     {'text': 'Pixar',
#      'displayText': 'Pixar',
#      'webSearchUrl': 'https://www.bing.com/images/search?q=Pixar&tq=%7b%22pq%22%3a%22car%22%2c%22qs%22%3a%5b%7b%22cv%22%3a%22car%22%2c%22pv%22%3a%22car%22%2c%22hps%22%3atrue%2c%22iqp%22%3afalse%7d%2c%7b%22cv%22%3a%22Pixar%22%2c%22pv%22%3a%22%22%2c%22hps%22%3afalse%2c%22iqp%22%3atrue%7d%5d%7d&FORM=IRQBPS',
#      'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Pixar&tq=%7b%22pq%22%3a%22car%22%2c%22qs%22%3a%5b%7b%22cv%22%3a%22car%22%2c%22pv%22%3a%22car%22%2c%22hps%22%3atrue%2c%22iqp%22%3afalse%7d%2c%7b%22cv%22%3a%22Pixar%22%2c%22pv%22%3a%22%22%2c%22hps%22%3afalse%2c%22iqp%22%3atrue%7d%5d%7d',
#      'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Pixar&pid=Api&mkt=en-WW&adlt=moderate&t=1'}}]}],
#  'relatedSearches': [{'text': 'Modern Cars',
#    'displayText': 'Modern Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Modern+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Modern+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Modern+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Yellow Car',
#    'displayText': 'Yellow Car',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Yellow+Car&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Yellow+Car',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Yellow+Car&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Car Truck',
#    'displayText': 'Car Truck',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Car+Truck&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Car+Truck',
#    'thumbnail': {'thumbnailUrl': 'https://tse2.mm.bing.net/th?q=Car+Truck&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Fast Cars',
#    'displayText': 'Fast Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Fast+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Fast+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=Fast+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Car Drawing',
#    'displayText': 'Car Drawing',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Car+Drawing&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Car+Drawing',
#    'thumbnail': {'thumbnailUrl': 'https://tse3.mm.bing.net/th?q=Car+Drawing&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Family Car',
#    'displayText': 'Family Car',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Family+Car&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Family+Car',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Family+Car&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Cute Cars',
#    'displayText': 'Cute Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Cute+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Cute+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Cute+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Muscle Cars',
#    'displayText': 'Muscle Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Muscle+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Muscle+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Muscle+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Sports Cars',
#    'displayText': 'Sports Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Sports+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Sports+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Sports+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Top Cars',
#    'displayText': 'Top Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Top+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Top+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Top+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Toyota Cars',
#    'displayText': 'Toyota Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Toyota+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Toyota+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=Toyota+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Orange Car',
#    'displayText': 'Orange Car',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Orange+Car&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Orange+Car',
#    'thumbnail': {'thumbnailUrl': 'https://tse3.mm.bing.net/th?q=Orange+Car&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Fancy Cars',
#    'displayText': 'Fancy Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Fancy+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Fancy+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse3.mm.bing.net/th?q=Fancy+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Car Keys',
#    'displayText': 'Car Keys',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Car+Keys&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Car+Keys',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Car+Keys&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Beetle Car',
#    'displayText': 'Beetle Car',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Beetle+Car&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Beetle+Car',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=Beetle+Car&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Green Car',
#    'displayText': 'Green Car',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Green+Car&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Green+Car',
#    'thumbnail': {'thumbnailUrl': 'https://tse2.mm.bing.net/th?q=Green+Car&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Super Cool Cars',
#    'displayText': 'Super Cool Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Super+Cool+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Super+Cool+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=Super+Cool+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Hot Cars',
#    'displayText': 'Hot Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Hot+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Hot+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Hot+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Car Logos',
#    'displayText': 'Car Logos',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Car+Logos&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Car+Logos',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Car+Logos&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Tesla Cars',
#    'displayText': 'Tesla Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Tesla+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Tesla+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Tesla+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Big Cars',
#    'displayText': 'Big Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Big+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Big+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=Big+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Car Seat',
#    'displayText': 'Car Seat',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Car+Seat&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Car+Seat',
#    'thumbnail': {'thumbnailUrl': 'https://tse2.mm.bing.net/th?q=Car+Seat&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Exotic Sports Cars',
#    'displayText': 'Exotic Sports Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Exotic+Sports+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Exotic+Sports+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse3.mm.bing.net/th?q=Exotic+Sports+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Car Graphics',
#    'displayText': 'Car Graphics',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Car+Graphics&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Car+Graphics',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=Car+Graphics&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Good Cars',
#    'displayText': 'Good Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Good+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Good+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse3.mm.bing.net/th?q=Good+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Luxury Sports Cars',
#    'displayText': 'Luxury Sports Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Luxury+Sports+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Luxury+Sports+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse2.mm.bing.net/th?q=Luxury+Sports+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Baby Car',
#    'displayText': 'Baby Car',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Baby+Car&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Baby+Car',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Baby+Car&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Benz Car',
#    'displayText': 'Benz Car',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Benz+Car&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Benz+Car',
#    'thumbnail': {'thumbnailUrl': 'https://tse2.mm.bing.net/th?q=Benz+Car&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Ugly Cars',
#    'displayText': 'Ugly Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Ugly+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Ugly+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Ugly+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Van Car',
#    'displayText': 'Van Car',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Van+Car&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Van+Car',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=Van+Car&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'BMW I8',
#    'displayText': 'BMW I8',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=BMW+I8&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=BMW+I8',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=BMW+I8&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Car Wheel',
#    'displayText': 'Car Wheel',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Car+Wheel&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Car+Wheel',
#    'thumbnail': {'thumbnailUrl': 'https://tse2.mm.bing.net/th?q=Car+Wheel&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Ferrari Car',
#    'displayText': 'Ferrari Car',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Ferrari+Car&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Ferrari+Car',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=Ferrari+Car&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Kids Cars',
#    'displayText': 'Kids Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Kids+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Kids+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse3.mm.bing.net/th?q=Kids+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Black Car',
#    'displayText': 'Black Car',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Black+Car&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Black+Car',
#    'thumbnail': {'thumbnailUrl': 'https://tse2.mm.bing.net/th?q=Black+Car&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Car Coming',
#    'displayText': 'Car Coming',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Car+Coming&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Car+Coming',
#    'thumbnail': {'thumbnailUrl': 'https://tse2.mm.bing.net/th?q=Car+Coming&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': '4x4 Cars',
#    'displayText': '4x4 Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=4x4+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=4x4+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=4x4+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Electric Cars',
#    'displayText': 'Electric Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Electric+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Electric+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Electric+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Car Wallpaper',
#    'displayText': 'Car Wallpaper',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Car+Wallpaper&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Car+Wallpaper',
#    'thumbnail': {'thumbnailUrl': 'https://tse3.mm.bing.net/th?q=Car+Wallpaper&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Audi',
#    'displayText': 'Audi',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Audi&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Audi',
#    'thumbnail': {'thumbnailUrl': 'https://tse2.mm.bing.net/th?q=Audi&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'RWD Cars',
#    'displayText': 'RWD Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=RWD+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=RWD+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse3.mm.bing.net/th?q=RWD+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'First Car',
#    'displayText': 'First Car',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=First+Car&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=First+Car',
#    'thumbnail': {'thumbnailUrl': 'https://tse3.mm.bing.net/th?q=First+Car&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Drift Cars',
#    'displayText': 'Drift Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Drift+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Drift+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Drift+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Top 5 Luxury Cars',
#    'displayText': 'Top 5 Luxury Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Top+5+Luxury+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Top+5+Luxury+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse3.mm.bing.net/th?q=Top+5+Luxury+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Car with Remote Control',
#    'displayText': 'Car with Remote Control',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Car+with+Remote+Control&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Car+with+Remote+Control',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=Car+with+Remote+Control&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Chevy Cars',
#    'displayText': 'Chevy Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Chevy+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Chevy+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Chevy+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Lots of Cars',
#    'displayText': 'Lots of Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Lots+of+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Lots+of+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse3.mm.bing.net/th?q=Lots+of+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Really Cool Cars',
#    'displayText': 'Really Cool Cars',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Really+Cool+Cars&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Really+Cool+Cars',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=Really+Cool+Cars&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Car Wraps',
#    'displayText': 'Car Wraps',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Car+Wraps&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Car+Wraps',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=Car+Wraps&pid=Api&mkt=en-WW&adlt=moderate&t=1'}},
#   {'text': 'Car Memes',
#    'displayText': 'Car Memes',
#    'webSearchUrl': 'https://www.bing.com/images/search?q=Car+Memes&FORM=IRPATC',
#    'searchLink': 'https://api.bing.microsoft.com/api/v7/images/search?q=Car+Memes',
#    'thumbnail': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=Car+Memes&pid=Api&mkt=en-WW&adlt=moderate&t=1'}}]}

# %%
# loop over the results
for v in results["value"]:
    # try to download the image
    try:
        # make a request to download the image
        print("Image fetching: {}".format(v["contentUrl"]))
        r = requests.get(v["contentUrl"], timeout=30)
        print(v["contentUrl"])
        
        # build the path to the output image
        ext = v["contentUrl"][v["contentUrl"].rfind("."):]
        
        p = os.path.join(output_dir, "{}{}".format(str(total).zfill(8), ext))
        print(p)
        
        # write the image to disk
        f = open(p, "wb")
        f.write(r.content)
        f.close()
        
    # catch any errors that would not enable us to download the image
    except Exception as e:
        
        # check to see if our exception is in our list of
        # exceptions to check for
        if type(e) in EXCEPTIONS:
            print("[INFO] skipping: {}".format(v["contentUrl"]))
            continue
            
    # try to load the image from disk
    
    image = cv2.imread(p)
    
    #cv2.imshow('web image',image)
    #cv2.waitKey(0)
    #cv2.destroyAllWindows()
    
    # if the image is `None` then we could not properly load the
    # image from disk (so it should be ignored)
    if image is None:
        print("[INFO] deleting: {}".format(p))
        os.remove(p)
        continue
    # update the counter
    total += 1
# Out:
# Image fetching: https://images.tweaktown.com/news/6/9/69796_03_sony-electric-car-yes-called-vision_full.png
# https://images.tweaktown.com/news/6/9/69796_03_sony-electric-car-yes-called-vision_full.png
# C:\labAnalytics\Lab01\car\00000000.png
# Image fetching: http://4.bp.blogspot.com/-6qW6H-KSJtM/TpA_xtD7NvI/AAAAAAAADXA/WMwNngDkPoE/s1600/sports-cars-pictures-car.jpg
# http://4.bp.blogspot.com/-6qW6H-KSJtM/TpA_xtD7NvI/AAAAAAAADXA/WMwNngDkPoE/s1600/sports-cars-pictures-car.jpg
# C:\labAnalytics\Lab01\car\00000001.jpg
# Image fetching: https://s3.caradvice.com.au/wp-content/uploads/2010/11/215_Kia_Kee_01-e1288670518879.jpg
# https://s3.caradvice.com.au/wp-content/uploads/2010/11/215_Kia_Kee_01-e1288670518879.jpg
# C:\labAnalytics\Lab01\car\00000002.jpg
# Image fetching: http://2.bp.blogspot.com/-xOYTiTbto1g/UEWQEHfBcYI/AAAAAAAAJFo/IrHrNVrsGoY/s1600/Bugatti+Veyron+Car+Wallpapers+3.jpg
# http://2.bp.blogspot.com/-xOYTiTbto1g/UEWQEHfBcYI/AAAAAAAAJFo/IrHrNVrsGoY/s1600/Bugatti+Veyron+Car+Wallpapers+3.jpg
# C:\labAnalytics\Lab01\car\00000003.jpg
# Image fetching: https://weneedfun.com/wp-content/uploads/2015/10/Sports-car-16.jpg
# https://weneedfun.com/wp-content/uploads/2015/10/Sports-car-16.jpg
# C:\labAnalytics\Lab01\car\00000004.jpg

# %% [markdown]
# ### Exercise
#
# #### 1. Create two folders with two groups of images for classification purpose
# #### 2. Increase the number of downloadable images
# #### 3. How would you change the size of images?
# #### 4. How would you change the width and height of images?
# #### 5. How would you download only PNG images?
#
#
# <br><br>
#
# [Filter query parameters - Reference for image query parameters](https://docs.microsoft.com/en-us/bing/search-apis/bing-image-search/reference/query-parameters)

# %% [markdown]
# ## Creating Datasets in Cloud environment

# %% [markdown]
# This is an example how image dataset was created within a cloud environment to detect objects in images. In this example GCP - [Google Cloud Platform Vision module](https://console.cloud.google.com/vision/datasets?project=tvdetection01) was used to upload, store, create, label, train, validate and export ML model to mobile, web or containerized platforms.
